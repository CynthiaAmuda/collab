# %% [markdown]
# <a href="https://colab.research.google.com/github/CynthiaAmuda/collab/blob/main/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sales=pd.read_excel('Sales Invoice Line.xlsx')

# %%
sales
# Out:
#      Document No_  Line No_        No_ Location Code  Quantity  Unit Price  \
# 0      SIVP412302     10000  ASM257436      PREMPARK       1.0       6.905
# 1      SIVP412302     20000  ASM245504      PREMPARK       1.0       5.435
# 2      SIVP412303     10000   P5362075      PREMPARK       2.0     257.885
# 3      SIVP412304     10000   P5365530      PREMPARK       1.0     265.123
# 4      SIVP412305     10000   P5310059      PREMPARK       1.0      14.140
# ...           ...       ...        ...           ...       ...         ...
# 4068   SIVP414527     30000   P5021203           NaN     900.0      71.536
# 4069   SIVP414527     40000   P5021203           NaN     900.0      71.496
# 4070   SIVP414527     50000   P5021203           NaN     900.0      72.006
# 4071   SIVP414527     60000   P5021203           NaN     900.0      71.756
# 4072   SIVP414635     30000   P5287949      PREMPARK       1.0     118.330
#
#        Unit Cost Type of Supply Code  Non Cancellable / Returnable
# ...

# %%
sales.isnull()
# Out:
#       Document No_  Line No_    No_  Location Code  Quantity  Unit Price  \
# 0            False     False  False          False     False       False
# 1            False     False  False          False     False       False
# 2            False     False  False          False     False       False
# 3            False     False  False          False     False       False
# 4            False     False  False          False     False       False
# ...            ...       ...    ...            ...       ...         ...
# 4068         False     False  False           True     False       False
# 4069         False     False  False           True     False       False
# 4070         False     False  False           True     False       False
# 4071         False     False  False           True     False       False
# 4072         False     False  False          False     False       False
#
#       Unit Cost  Type of Supply Code  Non Cancellable / Returnable
# ...

# %%
sales.shape
# Out:
# (4073, 9)

# %%
sales.size
# Out:
# 36657

# %%
sales.head()
# Out:
#   Document No_  Line No_        No_ Location Code  Quantity  Unit Price  \
# 0   SIVP412302     10000  ASM257436      PREMPARK       1.0       6.905
# 1   SIVP412302     20000  ASM245504      PREMPARK       1.0       5.435
# 2   SIVP412303     10000   P5362075      PREMPARK       2.0     257.885
# 3   SIVP412304     10000   P5365530      PREMPARK       1.0     265.123
# 4   SIVP412305     10000   P5310059      PREMPARK       1.0      14.140
#
#    Unit Cost Type of Supply Code  Non Cancellable / Returnable
# 0    1.97860           WAREHOUSE                             0
# 1    1.47792           WAREHOUSE                             0
# 2  234.52000           WAREHOUSE                             0
# 3  251.67000           WAREHOUSE                             1
# 4   12.83000           WAREHOUSE                             0

# %%
sales.tail()
# Out:
#      Document No_  Line No_       No_ Location Code  Quantity  Unit Price  \
# 4068   SIVP414527     30000  P5021203           NaN     900.0      71.536
# 4069   SIVP414527     40000  P5021203           NaN     900.0      71.496
# 4070   SIVP414527     50000  P5021203           NaN     900.0      72.006
# 4071   SIVP414527     60000  P5021203           NaN     900.0      71.756
# 4072   SIVP414635     30000  P5287949      PREMPARK       1.0     118.330
#
#       Unit Cost Type of Supply Code  Non Cancellable / Returnable
# 4068  70.182000          ELECTRONIC                             0
# 4069  70.252000          ELECTRONIC                             0
# 4070  70.362000          ELECTRONIC                             0
# 4071  70.032000          ELECTRONIC                             0
# 4072  94.768505           WAREHOUSE                             0

# %%
sales.isna().sum()
# Out:
# Document No_                       0
# Line No_                           0
# No_                                0
# Location Code                   1520
# Quantity                           0
# Unit Price                         0
# Unit Cost                          0
# Type of Supply Code                0
# Non Cancellable / Returnable       0
# dtype: int64

# %%
sales=sales.drop(columns=['Location Code'])

# %%
sales.isna().sum()
# Out:
# Document No_                    0
# Line No_                        0
# No_                             0
# Quantity                        0
# Unit Price                      0
# Unit Cost                       0
# Type of Supply Code             0
# Non Cancellable / Returnable    0
# dtype: int64
